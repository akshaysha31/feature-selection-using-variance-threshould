# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

# %%
df=pd.read_csv("train(1).csv")

# %%
df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
df.shape
# Out:
# (200000, 202)

# %%
x=df.drop(['target',],axis=1)

y=df['target']

# %%
x
# Out:
#              ID_code    var_0   var_1    var_2   var_3    var_4    var_5  \
# 0            train_0   8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834
# 1            train_1  11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433
# 2            train_2   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837
# 3            train_3  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361
# 4            train_4   9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486
# ...              ...      ...     ...      ...     ...      ...      ...
# 199995  train_199995  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081
# 199996  train_199996   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628
# 199997  train_199997  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086
# 199998  train_199998   9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339
# 199999  train_199999  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488
#
#          var_6    var_7   var_8  ...  var_190  var_191  var_192  var_193  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((134000, 201), (66000, 201))

# %%
x_train=x_train.drop("ID_code",axis=1)

# %% [markdown]
# ### apply the variance threshold

# %%
var_the=VarianceThreshold(threshold=0)
var_the.fit(x_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_the.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %% [markdown]
#  let find the non constant features

# %%
len(var_the.get_support())
# Out:
# 200

# %%
len(x_train.columns[var_the.get_support()])
# Out:
# 200

# %%
constant_column=[column for column in x_train.columns if column not in x_train.columns[var_the.get_support()]]

# %%
print(len(constant_column))
# Out:
# 0

# %%
for column in constant_column:
    print(column)

# %%
x_train.drop(constant_column,axis=1)
# Out:
#           var_0   var_1    var_2   var_3    var_4    var_5   var_6    var_7  \
# 18467   11.8343 -6.1515  12.3574  6.5865   9.4605 -12.0500  6.4799  20.4018
# 27683    7.2128  4.3895   8.8052  7.5041  12.0206  -3.8944  4.8014  20.0212
# 138657  16.9061 -3.3326  10.7128  5.4664  12.2687 -13.3964  4.8788  13.9910
# 148154   8.2861 -3.2550  12.3529  5.3664  11.0153   4.5804  4.4103  13.6726
# 41732   15.0694 -4.8835  13.7091  6.8672   9.0783 -16.1134  5.3372  14.6783
# ...         ...     ...      ...     ...      ...      ...     ...      ...
# 176963  15.0845 -1.1630   7.4419  8.1478  12.6517  12.6584  6.2026  13.5455
# 117952  10.5498  0.8018   7.0230  6.7595   8.1476   3.8299  5.7433  19.4838
# 173685   8.6165 -2.9485  11.2930  6.6443  11.6644  -1.5839  5.1576  18.1668
# 43567   10.7575 -2.9738   8.4717  8.5730  12.5846  -3.9031  5.4227  18.1202
# 199340  18.4176  2.8319   5.6394  2.9997  11.3781  -2.7525  5.6776  14.6353
#
# ...
